# %% [markdown]
# ## This notebook contains a few basic example of procedural terrain generation

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from procedural_noise_functions import *

# %% [markdown]
# ### Explicit noise

# %%
plt.imshow(generate_explicit(256,20,4,sigmas = [1,1,3,4]))

# %%
plt.imshow(generate_explicit(256,20,2,sigmas = [4,4,3,4]))

# %%
plt.imshow(generate_explicit(256,2,4,sigmas = [3,1,3,1]))

# %%
plt.imshow(generate_explicit(256,40,4,sigmas = [6,1,3,1]))

# %% [markdown]
# ### Perlin noise

# %%
plt.imshow(generate_perlin(256,12,3))

# %%
plt.imshow(generate_perlin(256,6,3))

# %%
plt.imshow(generate_perlin(256,30,3))

# %%
#Saving the images
plt.imsave("noise.png",generate_perlin(256,30,3), cmap = "Greys")
